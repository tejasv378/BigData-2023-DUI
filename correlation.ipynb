# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/Projects/DUI/processed_data.csv',index_col = False)
#df = df.iloc[:,:-1]
df
# Out:
#       Alcohol-Impaired Driving Deaths %  Adult Obesity %  \
# 0                                    32               35
# 1                                    32               30
# 2                                    38               40
# 3                                    21               41
# 4                                    15               39
# ...                                 ...              ...
# 2653                                 40               26
# 2654                                 18               34
# 2655                                 17               30
# 2656                                  0               29
# 2657                                 22               33
#
#       Food Environment Index (0-10)  Physically Inactive Adults %  \
# 0                               6.5                            32
# 1                               7.4                            28
# 2                               5.7                            42
# 3                               7.6                            38
# 4                               7.8                            33
# ...                             ...                           ...
# 2653                            8.1                            23
# 2654                            8.1                            25
# 2655                            8.3                            28
# 2656                            8.3                            26
# 2657                            7.6                            27
#
#       Access to Exercise Opportunities %  Food Insecure %  \
# 0                                     63               16
# 1                                     75               13
# 2                                     50               21
# 3                                     11               16
# 4                                     23               15
# ...                                  ...              ...
# 2653                                  45               12
# 2654                                  83               11
# 2655                                  79               13
# 2656                                  76               12
# 2657                                  28               12
#
#       Limited Access to Healthy Foods %  Insufficient Sleep % (Avg Hours < 7)  \
# 0                                    13                                    38
# 1                                     8                                    36
# 2                                    10                                    41
# 3                                     0                                    40
# 4                                     3                                    39
# ...                                 ...                                   ...
# 2653                                  4                                    33
# 2654                                  5                                    35
# 2655                                  1                                    36
# 2656                                  3                                    32
# 2657                                  9                                    34
#
#       Uninsured Adults % (Age < 65)  Some College % (Adults 25-44)  ...  \
# 0                                12                             61  ...
# 1                                14                             66  ...
# 2                                17                             38  ...
# 3                                14                             38  ...
# 4                                18                             56  ...
# ...                             ...                            ...  ...
# 2653                             16                             66  ...
# 2654                             16                             62  ...
# 2655                             16                             58  ...
# 2656                             18                             62  ...
# 2657                             15                             58  ...
#
#       Severe Housing Problems %  Drive Alone to Work %  \
# 0                            15                     87
# 1                            12                     83
# 2                            15                     84
# 3                            11                     88
# 4                            10                     88
# ...                         ...                    ...
# 2653                          6                     70
# 2654                         10                     76
# 2655                         11                     79
# 2656                          8                     84
# 2657                         13                     69
#
#       Drive Alone Long Commute % (Minutes > 30)  Homeowners %  \
# 0                                            41            75
# 1                                            38            77
# 2                                            37            62
# 3                                            55            75
# 4                                            60            76
# ...                                         ...           ...
# 2653                                         27            83
# 2654                                         19            75
# 2655                                         18            77
# 2656                                          8            73
# 2657                                         21            84
#
#       Broadband Internet Access %  High School Completion % (Adults >= 25)  \
# 0                              83                                       89
# 1                              85                                       90
# 2                              65                                       75
# 3                              76                                       81
# 4                              80                                       83
# ...                           ...                                      ...
# 2653                           88                                       95
# 2654                           87                                       93
# 2655                           91                                       93
# 2656                           83                                       92
# 2657                           80                                       93
#
#       white_not_hispanic %  per_capita_income  age_over_65 %  Risk Level
# 0                     74.6              29819           15.0           1
# 1                     83.1              32626           20.0           1
# 2                     45.8              18473           18.6           1
# 3                     74.5              20778           15.9           1
# 4                     86.9              24747           17.9           0
# ...                    ...                ...            ...         ...
# 2653                  89.3              35874           17.8           1
# 2654                  79.6              32603           11.4           0
# 2655                  87.5              28159           13.0           0
# 2656                  81.9              28101           21.1           0
# 2657                  96.4              28531           19.4           1
#
# [2658 rows x 25 columns]

# %%
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-12-5198832b8e61> in <cell line: 2>()
#       1 #densty plot  'white_not_hispanic %',  'per_capita_income', 'age_over_65 %',
# ----> 2 ax = sns.histplot(x = df['white_not_hispanic %'], hue=df['Risk Level'], multiple="dodge", stat='density', shrink=0.8, bins=[10, 20, 30, 40, 50, 60, 70, 80, 90], common_norm=False)
#       3 ax.spines["top"].set_visible(False), ax.spines["right"].set_visible(False)
#       4 for p in ax.patches:
#       5     ax.annotate('{:.3f}'.format(p.get_height()), (p.get_x()+.05, p.get_height()+0.001), rotation = 75)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1430     if p.univariate:
#    1431
# -> 1432         p.plot_univariate_histogram(
#    1433             multiple=multiple,
#    1434             element=element,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     495             # Pack the histogram data and metadata together
#     496             edges = edges + (1 - shrink) / 2 * widths
# --> 497             widths *= shrink
#     498             index = pd.MultiIndex.from_arrays([
#     499                 pd.Index(edges, name="edges"),
#
# UFuncTypeError: Cannot cast ufunc 'multiply' output from dtype('float64') to dtype('int64') with casting rule 'same_kind'

# %%
df.corr(numeric_only=True)
# Out:
#                                            Alcohol-Impaired Driving Deaths %  \
# Alcohol-Impaired Driving Deaths %                                   1.000000
# Adult Obesity %                                                    -0.063028
# Food Environment Index (0-10)                                       0.096506
# Physically Inactive Adults %                                       -0.151480
# Access to Exercise Opportunities %                                  0.012463
# Food Insecure %                                                    -0.115324
# Limited Access to Healthy Foods %                                  -0.034273
# Insufficient Sleep % (Avg Hours < 7)                               -0.111351
# Uninsured Adults % (Age < 65)                                      -0.151671
# Some College % (Adults 25-44)                                       0.084553
# School Segregation Index                                            0.056961
# Unemployment % (Age >= 16)                                          0.055227
# Median Household Income                                             0.029045
# Children Single-Parent Households %                                -0.014201
# Annual Average Violent Crimes                                      -0.027950
# Severe Housing Problems %                                          -0.023528
# Drive Alone to Work %                                              -0.056578
# Drive Alone Long Commute % (Minutes > 30)                          -0.011699
# Homeowners %                                                        0.049860
# Broadband Internet Access %                                         0.060445
# High School Completion % (Adults >= 25)                             0.130890
# white_not_hispanic %                                                0.042588
# per_capita_income                                                   0.055486
# age_over_65 %                                                       0.050630
# Risk Level                                                          0.683560
#
#                                            Adult Obesity %  \
# Alcohol-Impaired Driving Deaths %                -0.063028
# Adult Obesity %                                   1.000000
# Food Environment Index (0-10)                    -0.481376
# Physically Inactive Adults %                      0.764818
# Access to Exercise Opportunities %               -0.423658
# Food Insecure %                                   0.536338
# Limited Access to Healthy Foods %                 0.204899
# Insufficient Sleep % (Avg Hours < 7)              0.539474
# Uninsured Adults % (Age < 65)                     0.305139
# Some College % (Adults 25-44)                    -0.537045
# School Segregation Index                         -0.015166
# Unemployment % (Age >= 16)                        0.083244
# Median Household Income                          -0.623848
# Children Single-Parent Households %               0.404412
# Annual Average Violent Crimes                    -0.174875
# Severe Housing Problems %                        -0.131680
# Drive Alone to Work %                             0.456109
# Drive Alone Long Commute % (Minutes > 30)        -0.032607
# Homeowners %                                     -0.005312
# Broadband Internet Access %                      -0.564267
# High School Completion % (Adults >= 25)          -0.507698
# white_not_hispanic %                             -0.159248
# per_capita_income                                -0.602106
# age_over_65 %                                    -0.047745
# Risk Level                                       -0.094427
#
#                                            Food Environment Index (0-10)  \
# Alcohol-Impaired Driving Deaths %                               0.096506
# Adult Obesity %                                                -0.481376
# Food Environment Index (0-10)                                   1.000000
# Physically Inactive Adults %                                   -0.590199
# Access to Exercise Opportunities %                              0.315443
# Food Insecure %                                                -0.824689
# Limited Access to Healthy Foods %                              -0.764215
# Insufficient Sleep % (Avg Hours < 7)                           -0.399370
# Uninsured Adults % (Age < 65)                                  -0.466894
# Some College % (Adults 25-44)                                   0.478554
# School Segregation Index                                       -0.069666
# Unemployment % (Age >= 16)                                     -0.200432
# Median Household Income                                         0.653091
# Children Single-Parent Households %                            -0.468515
# Annual Average Violent Crimes                                   0.083770
# Severe Housing Problems %                                      -0.190236
# Drive Alone to Work %                                          -0.134389
# Drive Alone Long Commute % (Minutes > 30)                       0.132273
# Homeowners %                                                    0.188418
# Broadband Internet Access %                                     0.537681
# High School Completion % (Adults >= 25)                         0.466596
# white_not_hispanic %                                            0.260515
# per_capita_income                                               0.570324
# age_over_65 %                                                  -0.080999
# Risk Level                                                      0.122387
#
#                                            Physically Inactive Adults %  \
# Alcohol-Impaired Driving Deaths %                             -0.151480
# Adult Obesity %                                                0.764818
# Food Environment Index (0-10)                                 -0.590199
# Physically Inactive Adults %                                   1.000000
# Access to Exercise Opportunities %                            -0.429032
# Food Insecure %                                                0.692190
# Limited Access to Healthy Foods %                              0.214218
# Insufficient Sleep % (Avg Hours < 7)                           0.641191
# Uninsured Adults % (Age < 65)                                  0.521500
# Some College % (Adults 25-44)                                 -0.699270
# School Segregation Index                                      -0.030547
# Unemployment % (Age >= 16)                                     0.079512
# Median Household Income                                       -0.670968
# Children Single-Parent Households %                            0.479024
# Annual Average Violent Crimes                                 -0.094449
# Severe Housing Problems %                                      0.019854
# Drive Alone to Work %                                          0.341425
# Drive Alone Long Commute % (Minutes > 30)                      0.049133
# Homeowners %                                                  -0.100109
# Broadband Internet Access %                                   -0.649651
# High School Completion % (Adults >= 25)                       -0.721793
# white_not_hispanic %                                          -0.274955
# per_capita_income                                             -0.644006
# age_over_65 %                                                 -0.056559
# Risk Level                                                    -0.157667
#
#                                            Access to Exercise Opportunities %  \
# Alcohol-Impaired Driving Deaths %                                    0.012463
# Adult Obesity %                                                     -0.423658
# Food Environment Index (0-10)                                        0.315443
# Physically Inactive Adults %                                        -0.429032
# Access to Exercise Opportunities %                                   1.000000
# Food Insecure %                                                     -0.322924
# Limited Access to Healthy Foods %                                   -0.168441
# Insufficient Sleep % (Avg Hours < 7)                                -0.230954
# Uninsured Adults % (Age < 65)                                       -0.205474
# Some College % (Adults 25-44)                                        0.450617
# School Segregation Index                                             0.184699
# Unemployment % (Age >= 16)                                           0.155310
# Median Household Income                                              0.441320
# Children Single-Parent Households %                                 -0.059399
# Annual Average Violent Crimes                                        0.282341
# Severe Housing Problems %                                            0.280819
# Drive Alone to Work %                                               -0.233055
# Drive Alone Long Commute % (Minutes > 30)                           -0.184778
# Homeowners %                                                        -0.352720
# Broadband Internet Access %                                          0.512398
# High School Completion % (Adults >= 25)                              0.292596
# white_not_hispanic %                                                -0.102409
# per_capita_income                                                    0.424900
# age_over_65 %                                                       -0.185064
# Risk Level                                                           0.094854
#
#                                            Food Insecure %  \
# Alcohol-Impaired Driving Deaths %                -0.115324
# Adult Obesity %                                   0.536338
# Food Environment Index (0-10)                    -0.824689
# Physically Inactive Adults %                      0.692190
# Access to Exercise Opportunities %               -0.322924
# Food Insecure %                                   1.000000
# Limited Access to Healthy Foods %                 0.271314
# Insufficient Sleep % (Avg Hours < 7)              0.538271
# Uninsured Adults % (Age < 65)                     0.467683
# Some College % (Adults 25-44)                    -0.580595
# School Segregation Index                          0.021163
# Unemployment % (Age >= 16)                        0.280666
# Median Household Income                          -0.737801
# Children Single-Parent Households %               0.497616
# Annual Average Violent Crimes                    -0.065388
# Severe Housing Problems %                         0.200980
# Drive Alone to Work %                             0.198848
# Drive Alone Long Commute % (Minutes > 30)        -0.035071
# Homeowners %                                     -0.166424
# Broadband Internet Access %                      -0.610797
# High School Completion % (Adults >= 25)          -0.553627
# white_not_hispanic %                             -0.191511
# per_capita_income                                -0.628771
# age_over_65 %                                     0.101524
# Risk Level                                       -0.119440
#
#                                            Limited Access to Healthy Foods %  \
# Alcohol-Impaired Driving Deaths %                                  -0.034273
# Adult Obesity %                                                     0.204899
# Food Environment Index (0-10)                                      -0.764215
# Physically Inactive Adults %                                        0.214218
# Access to Exercise Opportunities %                                 -0.168441
# Food Insecure %                                                     0.271314
# Limited Access to Healthy Foods %                                   1.000000
# Insufficient Sleep % (Avg Hours < 7)                                0.066539
# Uninsured Adults % (Age < 65)                                       0.261391
# Some College % (Adults 25-44)                                      -0.152815
# School Segregation Index                                            0.095271
# Unemployment % (Age >= 16)                                          0.021867
# Median Household Income                                            -0.269552
# Children Single-Parent Households %                                 0.229960
# Annual Average Violent Crimes                                      -0.065247
# Severe Housing Problems %                                           0.094576
# Drive Alone to Work %                                               0.000963
# Drive Alone Long Commute % (Minutes > 30)                          -0.181556
# Homeowners %                                                       -0.130391
# Broadband Internet Access %                                        -0.220318
# High School Completion % (Adults >= 25)                            -0.163598
# white_not_hispanic %                                               -0.224394
# per_capita_income                                                  -0.252806
# age_over_65 %                                                       0.023840
# Risk Level                                                         -0.072930
#
#                                            Insufficient Sleep % (Avg Hours < 7)  \
# Alcohol-Impaired Driving Deaths %                                     -0.111351
# Adult Obesity %                                                        0.539474
# Food Environment Index (0-10)                                         -0.399370
# Physically Inactive Adults %                                           0.641191
# Access to Exercise Opportunities %                                    -0.230954
# Food Insecure %                                                        0.538271
# Limited Access to Healthy Foods %                                      0.066539
# Insufficient Sleep % (Avg Hours < 7)                                   1.000000
# Uninsured Adults % (Age < 65)                                          0.207599
# Some College % (Adults 25-44)                                         -0.520093
# School Segregation Index                                               0.011437
# Unemployment % (Age >= 16)                                             0.353394
# Median Household Income                                               -0.447598
# Children Single-Parent Households %                                    0.500704
# Annual Average Violent Crimes                                          0.034688
# Severe Housing Problems %                                              0.139638
# Drive Alone to Work %                                                  0.285761
# Drive Alone Long Commute % (Minutes > 30)                              0.274250
# Homeowners %                                                          -0.112505
# Broadband Internet Access %                                           -0.398949
# High School Completion % (Adults >= 25)                               -0.476341
# white_not_hispanic %                                                  -0.200804
# per_capita_income                                                     -0.415425
# age_over_65 %                                                         -0.049313
# Risk Level                                                            -0.048903
#
#                                            Uninsured Adults % (Age < 65)  \
# Alcohol-Impaired Driving Deaths %                              -0.151671
# Adult Obesity %                                                 0.305139
# Food Environment Index (0-10)                                  -0.466894
# Physically Inactive Adults %                                    0.521500
# Access to Exercise Opportunities %                             -0.205474
# Food Insecure %                                                 0.467683
# Limited Access to Healthy Foods %                               0.261391
# Insufficient Sleep % (Avg Hours < 7)                            0.207599
# Uninsured Adults % (Age < 65)                                   1.000000
# Some College % (Adults 25-44)                                  -0.499565
# School Segregation Index                                       -0.019302
# Unemployment % (Age >= 16)                                     -0.058768
# Median Household Income                                        -0.362467
# Children Single-Parent Households %                             0.235237
# Annual Average Violent Crimes                                  -0.004071
# Severe Housing Problems %                                       0.196291
# Drive Alone to Work %                                           0.036720
# Drive Alone Long Commute % (Minutes > 30)                      -0.035861
# Homeowners %                                                   -0.086959
# Broadband Internet Access %                                    -0.376301
# High School Completion % (Adults >= 25)                        -0.624471
# white_not_hispanic %                                           -0.479006
# per_capita_income                                              -0.416724
# age_over_65 %                                                  -0.045982
# Risk Level                                                     -0.169665
#
#                                            Some College % (Adults 25-44)  ...  \
# Alcohol-Impaired Driving Deaths %                               0.084553  ...
# Adult Obesity %                                                -0.537045  ...
# Food Environment Index (0-10)                                   0.478554  ...
# Physically Inactive Adults %                                   -0.699270  ...
# Access to Exercise Opportunities %                              0.450617  ...
# Food Insecure %                                                -0.580595  ...
# Limited Access to Healthy Foods %                              -0.152815  ...
# Insufficient Sleep % (Avg Hours < 7)                           -0.520093  ...
# Uninsured Adults % (Age < 65)                                  -0.499565  ...
# Some College % (Adults 25-44)                                   1.000000  ...
# School Segregation Index                                        0.093850  ...
# Unemployment % (Age >= 16)                                     -0.160100  ...
# Median Household Income                                         0.600588  ...
# Children Single-Parent Households %                            -0.337615  ...
# Annual Average Violent Crimes                                   0.144222  ...
# Severe Housing Problems %                                      -0.009683  ...
# Drive Alone to Work %                                          -0.237423  ...
# Drive Alone Long Commute % (Minutes > 30)                      -0.136170  ...
# Homeowners %                                                   -0.107976  ...
# Broadband Internet Access %                                     0.630335  ...
# High School Completion % (Adults >= 25)                         0.750503  ...
# white_not_hispanic %                                            0.213782  ...
# per_capita_income                                               0.622183  ...
# age_over_65 %                                                  -0.108232  ...
# Risk Level                                                      0.106246  ...
#
#                                            Severe Housing Problems %  \
# Alcohol-Impaired Driving Deaths %                          -0.023528
# Adult Obesity %                                            -0.131680
# Food Environment Index (0-10)                              -0.190236
# Physically Inactive Adults %                                0.019854
# Access to Exercise Opportunities %                          0.280819
# Food Insecure %                                             0.200980
# Limited Access to Healthy Foods %                           0.094576
# Insufficient Sleep % (Avg Hours < 7)                        0.139638
# Uninsured Adults % (Age < 65)                               0.196291
# Some College % (Adults 25-44)                              -0.009683
# School Segregation Index                                    0.291196
# Unemployment % (Age >= 16)                                  0.422968
# Median Household Income                                    -0.003119
# Children Single-Parent Households %                         0.360662
# Annual Average Violent Crimes                               0.349086
# Severe Housing Problems %                                   1.000000
# Drive Alone to Work %                                      -0.349973
# Drive Alone Long Commute % (Minutes > 30)                   0.023936
# Homeowners %                                               -0.572531
# Broadband Internet Access %                                 0.035000
# High School Completion % (Adults >= 25)                    -0.233355
# white_not_hispanic %                                       -0.509690
# per_capita_income                                           0.007178
# age_over_65 %                                              -0.211163
# Risk Level                                                  0.051040
#
#                                            Drive Alone to Work %  \
# Alcohol-Impaired Driving Deaths %                      -0.056578
# Adult Obesity %                                         0.456109
# Food Environment Index (0-10)                          -0.134389
# Physically Inactive Adults %                            0.341425
# Access to Exercise Opportunities %                     -0.233055
# Food Insecure %                                         0.198848
# Limited Access to Healthy Foods %                       0.000963
# Insufficient Sleep % (Avg Hours < 7)                    0.285761
# Uninsured Adults % (Age < 65)                           0.036720
# Some College % (Adults 25-44)                          -0.237423
# School Segregation Index                               -0.157193
# Unemployment % (Age >= 16)                             -0.038887
# Median Household Income                                -0.255949
# Children Single-Parent Households %                     0.159438
# Annual Average Violent Crimes                          -0.241957
# Severe Housing Problems %                              -0.349973
# Drive Alone to Work %                                   1.000000
# Drive Alone Long Commute % (Minutes > 30)               0.051503
# Homeowners %                                            0.284673
# Broadband Internet Access %                            -0.223833
# High School Completion % (Adults >= 25)                -0.131068
# white_not_hispanic %                                    0.087180
# per_capita_income                                      -0.293078
# age_over_65 %                                          -0.016592
# Risk Level                                             -0.021657
#
#                                            Drive Alone Long Commute % (Minutes > 30)  \
# Alcohol-Impaired Driving Deaths %                                          -0.011699
# Adult Obesity %                                                            -0.032607
# Food Environment Index (0-10)                                               0.132273
# Physically Inactive Adults %                                                0.049133
# Access to Exercise Opportunities %                                         -0.184778
# Food Insecure %                                                            -0.035071
# Limited Access to Healthy Foods %                                          -0.181556
# Insufficient Sleep % (Avg Hours < 7)                                        0.274250
# Uninsured Adults % (Age < 65)                                              -0.035861
# Some College % (Adults 25-44)                                              -0.136170
# School Segregation Index                                                   -0.061576
# Unemployment % (Age >= 16)                                                  0.152149
# Median Household Income                                                     0.212507
# Children Single-Parent Households %                                         0.010834
# Annual Average Violent Crimes                                               0.099329
# Severe Housing Problems %                                                   0.023936
# Drive Alone to Work %                                                       0.051503
# Drive Alone Long Commute % (Minutes > 30)                                   1.000000
# Homeowners %                                                                0.321421
# Broadband Internet Access %                                                -0.014175
# High School Completion % (Adults >= 25)                                    -0.085660
# white_not_hispanic %                                                       -0.032773
# per_capita_income                                                           0.083452
# age_over_65 %                                                              -0.030104
# Risk Level                                                                  0.043981
#
#                                            Homeowners %  \
# Alcohol-Impaired Driving Deaths %              0.049860
# Adult Obesity %                               -0.005312
# Food Environment Index (0-10)                  0.188418
# Physically Inactive Adults %                  -0.100109
# Access to Exercise Opportunities %            -0.352720
# Food Insecure %                               -0.166424
# Limited Access to Healthy Foods %             -0.130391
# Insufficient Sleep % (Avg Hours < 7)          -0.112505
# Uninsured Adults % (Age < 65)                 -0.086959
# Some College % (Adults 25-44)                 -0.107976
# School Segregation Index                      -0.287053
# Unemployment % (Age >= 16)                    -0.161082
# Median Household Income                        0.097180
# Children Single-Parent Households %           -0.385393
# Annual Average Violent Crimes                 -0.334842
# Severe Housing Problems %                     -0.572531
# Drive Alone to Work %                          0.284673
# Drive Alone Long Commute % (Minutes > 30)      0.321421
# Homeowners %                                   1.000000
# Broadband Internet Access %                   -0.068837
# High School Completion % (Adults >= 25)        0.131266
# white_not_hispanic %                           0.407560
# per_capita_income                             -0.002218
# age_over_65 %                                  0.385278
# Risk Level                                    -0.010625
#
#                                            Broadband Internet Access %  \
# Alcohol-Impaired Driving Deaths %                             0.060445
# Adult Obesity %                                              -0.564267
# Food Environment Index (0-10)                                 0.537681
# Physically Inactive Adults %                                 -0.649651
# Access to Exercise Opportunities %                            0.512398
# Food Insecure %                                              -0.610797
# Limited Access to Healthy Foods %                            -0.220318
# Insufficient Sleep % (Avg Hours < 7)                         -0.398949
# Uninsured Adults % (Age < 65)                                -0.376301
# Some College % (Adults 25-44)                                 0.630335
# School Segregation Index                                      0.044564
# Unemployment % (Age >= 16)                                   -0.052428
# Median Household Income                                       0.704170
# Children Single-Parent Households %                          -0.407146
# Annual Average Violent Crimes                                 0.169682
# Severe Housing Problems %                                     0.035000
# Drive Alone to Work %                                        -0.223833
# Drive Alone Long Commute % (Minutes > 30)                    -0.014175
# Homeowners %                                                 -0.068837
# Broadband Internet Access %                                   1.000000
# High School Completion % (Adults >= 25)                       0.569203
# white_not_hispanic %                                          0.175118
# per_capita_income                                             0.592015
# age_over_65 %                                                -0.206436
# Risk Level                                                    0.130656
#
#                                            High School Completion % (Adults >= 25)  \
# Alcohol-Impaired Driving Deaths %                                         0.130890
# Adult Obesity %                                                          -0.507698
# Food Environment Index (0-10)                                             0.466596
# Physically Inactive Adults %                                             -0.721793
# Access to Exercise Opportunities %                                        0.292596
# Food Insecure %                                                          -0.553627
# Limited Access to Healthy Foods %                                        -0.163598
# Insufficient Sleep % (Avg Hours < 7)                                     -0.476341
# Uninsured Adults % (Age < 65)                                            -0.624471
# Some College % (Adults 25-44)                                             0.750503
# School Segregation Index                                                 -0.011000
# Unemployment % (Age >= 16)                                               -0.195888
# Median Household Income                                                   0.486606
# Children Single-Parent Households %                                      -0.385022
# Annual Average Violent Crimes                                            -0.011519
# Severe Housing Problems %                                                -0.233355
# Drive Alone to Work %                                                    -0.131068
# Drive Alone Long Commute % (Minutes > 30)                                -0.085660
# Homeowners %                                                              0.131266
# Broadband Internet Access %                                               0.569203
# High School Completion % (Adults >= 25)                                   1.000000
# white_not_hispanic %                                                      0.473859
# per_capita_income                                                         0.537442
# age_over_65 %                                                             0.129623
# Risk Level                                                                0.131285
#
#                                            white_not_hispanic %  \
# Alcohol-Impaired Driving Deaths %                      0.042588
# Adult Obesity %                                       -0.159248
# Food Environment Index (0-10)                          0.260515
# Physically Inactive Adults %                          -0.274955
# Access to Exercise Opportunities %                    -0.102409
# Food Insecure %                                       -0.191511
# Limited Access to Healthy Foods %                     -0.224394
# Insufficient Sleep % (Avg Hours < 7)                  -0.200804
# Uninsured Adults % (Age < 65)                         -0.479006
# Some College % (Adults 25-44)                          0.213782
# School Segregation Index                              -0.293572
# Unemployment % (Age >= 16)                            -0.254687
# Median Household Income                                0.061586
# Children Single-Parent Households %                   -0.494044
# Annual Average Violent Crimes                         -0.256878
# Severe Housing Problems %                             -0.509690
# Drive Alone to Work %                                  0.087180
# Drive Alone Long Commute % (Minutes > 30)             -0.032773
# Homeowners %                                           0.407560
# Broadband Internet Access %                            0.175118
# High School Completion % (Adults >= 25)                0.473859
# white_not_hispanic %                                   1.000000
# per_capita_income                                      0.147558
# age_over_65 %                                          0.364366
# Risk Level                                             0.002417
#
#                                            per_capita_income  age_over_65 %  \
# Alcohol-Impaired Driving Deaths %                   0.055486       0.050630
# Adult Obesity %                                    -0.602106      -0.047745
# Food Environment Index (0-10)                       0.570324      -0.080999
# Physically Inactive Adults %                       -0.644006      -0.056559
# Access to Exercise Opportunities %                  0.424900      -0.185064
# Food Insecure %                                    -0.628771       0.101524
# Limited Access to Healthy Foods %                  -0.252806       0.023840
# Insufficient Sleep % (Avg Hours < 7)               -0.415425      -0.049313
# Uninsured Adults % (Age < 65)                      -0.416724      -0.045982
# Some College % (Adults 25-44)                       0.622183      -0.108232
# School Segregation Index                            0.082546      -0.161999
# Unemployment % (Age >= 16)                         -0.052705      -0.007828
# Median Household Income                             0.727290      -0.215771
# Children Single-Parent Households %                -0.328332      -0.025257
# Annual Average Violent Crimes                       0.177659      -0.167471
# Severe Housing Problems %                           0.007178      -0.211163
# Drive Alone to Work %                              -0.293078      -0.016592
# Drive Alone Long Commute % (Minutes > 30)           0.083452      -0.030104
# Homeowners %                                       -0.002218       0.385278
# Broadband Internet Access %                         0.592015      -0.206436
# High School Completion % (Adults >= 25)             0.537442       0.129623
# white_not_hispanic %                                0.147558       0.364366
# per_capita_income                                   1.000000      -0.062180
# age_over_65 %                                      -0.062180       1.000000
# Risk Level                                          0.098603      -0.014130
#
#                                            Risk Level
# Alcohol-Impaired Driving Deaths %            0.683560
# Adult Obesity %                             -0.094427
# Food Environment Index (0-10)                0.122387
# Physically Inactive Adults %                -0.157667
# Access to Exercise Opportunities %           0.094854
# Food Insecure %                             -0.119440
# Limited Access to Healthy Foods %           -0.072930
# Insufficient Sleep % (Avg Hours < 7)        -0.048903
# Uninsured Adults % (Age < 65)               -0.169665
# Some College % (Adults 25-44)                0.106246
# School Segregation Index                     0.058074
# Unemployment % (Age >= 16)                   0.087696
# Median Household Income                      0.103640
# Children Single-Parent Households %          0.010094
# Annual Average Violent Crimes                0.040463
# Severe Housing Problems %                    0.051040
# Drive Alone to Work %                       -0.021657
# Drive Alone Long Commute % (Minutes > 30)    0.043981
# Homeowners %                                -0.010625
# Broadband Internet Access %                  0.130656
# High School Completion % (Adults >= 25)      0.131285
# white_not_hispanic %                         0.002417
# per_capita_income                            0.098603
# age_over_65 %                               -0.014130
# Risk Level                                   1.000000
#
# [25 rows x 25 columns]

# %%
plt.figure(figsize=(20,12))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
# Out:
# <Axes: >

# %%
df.columns
# Out:
# Index(['Alcohol-Impaired Driving Deaths %', 'Adult Obesity %',
#        'Food Environment Index (0-10)', 'Physically Inactive Adults %',
#        'Access to Exercise Opportunities %', 'Food Insecure %',
#        'Limited Access to Healthy Foods %',
#        'Insufficient Sleep % (Avg Hours < 7)', 'Uninsured Adults % (Age < 65)',
#        'Some College % (Adults 25-44)', 'School Segregation Index',
#        'Unemployment % (Age >= 16)', 'Median Household Income',
#        'Children Single-Parent Households %', 'Annual Average Violent Crimes',
#        'Severe Housing Problems %', 'Drive Alone to Work %',
#        'Drive Alone Long Commute % (Minutes > 30)', 'Homeowners %',
#        'Broadband Internet Access %',
#        'High School Completion % (Adults >= 25)', 'white_not_hispanic %',
#        'per_capita_income', 'age_over_65 %', 'Risk Level'],
#       dtype='object')

# %%
df= df.drop([  'Adult Obesity %',
       'Food Environment Index (0-10)', 'Physically Inactive Adults %',
       'Access to Exercise Opportunities %', 'Food Insecure %',
       'Limited Access to Healthy Foods %',
       'Insufficient Sleep % (Avg Hours < 7)', 'Uninsured Adults % (Age < 65)',
       'Some College % (Adults 25-44)', 'School Segregation Index',
       'Unemployment % (Age >= 16)', 'Median Household Income',
       'Children Single-Parent Households %', 'Annual Average Violent Crimes',
       'Severe Housing Problems %', 'Drive Alone to Work %',
       'Drive Alone Long Commute % (Minutes > 30)', 'Homeowners %',
       'Broadband Internet Access %',
       'High School Completion % (Adults >= 25)'], axis=1)

# %%
df
# Out:
#       Alcohol-Impaired Driving Deaths %  white_not_hispanic %  \
# 0                                    32                  74.6
# 1                                    32                  83.1
# 2                                    38                  45.8
# 3                                    21                  74.5
# 4                                    15                  86.9
# ...                                 ...                   ...
# 2653                                 40                  89.3
# 2654                                 18                  79.6
# 2655                                 17                  87.5
# 2656                                  0                  81.9
# 2657                                 22                  96.4
#
#       per_capita_income  age_over_65 %  Risk Level
# 0                 29819           15.0           1
# 1                 32626           20.0           1
# 2                 18473           18.6           1
# 3                 20778           15.9           1
# 4                 24747           17.9           0
# ...                 ...            ...         ...
# 2653              35874           17.8           1
# 2654              32603           11.4           0
# 2655              28159           13.0           0
# 2656              28101           21.1           0
# 2657              28531           19.4           1
#
# [2658 rows x 5 columns]

# %%
plt.figure(figsize=(5,4))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='Blues')
# Out:
# <Axes: >
